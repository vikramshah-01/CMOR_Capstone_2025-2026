# %%
import numpy as np
import matplotlib.pyplot as plt
from src.new_time_dependent_model import time_dependent_norwood

# %%
time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
                           E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)




HR = 70
t0 = 0
tf = 5*(1/HR)
dt = 0.001
V_a0 = 23
V_v0 = 46
K_a = 5 * (10**(-4))
K_v = 5 * (10**(-4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
#       2                            E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)
#
# NameError: name 't0' is not defined

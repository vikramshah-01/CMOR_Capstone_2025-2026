# %%
import numpy as np
import matplotlib.pyplot as plt
from src.new_time_dependent_model import time_dependent_norwood

# %%
HR = 70
t0 = 0
tf = 5*(1/HR)
dt = 0.001
V_a0 = 23
V_v0 = 46
K_a = 5 * (10**(-4))
K_v = 5 * (10**(-4))

gamma_int = 5*(10**(-3))
gamma_ext = 3*(10**(-3))
L_int = 5*(10**(-3))
L_ext = 5*(10**(-3))
B_int = 3*(10**(-3))
B_ext = 3*(10**(-3))
R_int = 1*(10**(-3))
R_ext = 1*(10**(-3))

R_s   = 17.5
R_p   = 1.79
R_BTS = 5.0

V_total = 5186.99

# Googled
C_SA = 1.6
C_PA = 4.1
C_SV = 60
C_PV = 25

# From table 4
# Atrium
E_min_a = 1.2
E_max_a = 12
t_onset_a = 0.85
m_1a = 3
tau_1a = 0.11
m_2a = 27
tau_2a = 0.18

# Ventricle
E_min_v = 1.2
E_max_v = 120
t_onset_v = 0.0
m_1v = 3
tau_1v = 0.27
m_2v = 27
tau_2v = 0.45

# x_0 = [p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SA, Q_SV, Q_PA, Q_PV, P_SA, P_SV, P_PA, P_PV]
# Really only and p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SV, Q_PV, and P_SA are need so the others can be set to zero. 
x_0 = [p_a, p_v, Q_int, Q_ext, V_a, V_v, 0, Q_SV, 0, Q_PV, P_SA, 0, 0, 0]



time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
                           E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 24
#      20 R_p   = 1.79
#      21 R_BTS = 5.0
# ---> 24 time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
#      25                            E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)
#
# NameError: name 'x0' is not defined

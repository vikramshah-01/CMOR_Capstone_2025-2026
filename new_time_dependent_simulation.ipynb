# %%
import numpy as np
import matplotlib.pyplot as plt
from src.new_time_dependent_model import time_dependent_norwood
from src.fixed_point_init import generate_x0_fixed_point_ra_rv

# %%
HR = 70
t0 = 0
tf = 5*(1/HR)
dt = 0.001
V_a0 = 23
V_v0 = 46
K_a = 5 * (10**(-4))
K_v = 5 * (10**(-4))

gamma_int = 5*(10**(-3))
gamma_ext = 3*(10**(-3))
L_int = 5*(10**(-3))
L_ext = 5*(10**(-3))
B_int = 3*(10**(-3))
B_ext = 3*(10**(-3))
R_int = 1*(10**(-3))
R_ext = 1*(10**(-3))

R_s   = 17.5
R_p   = 1.79
R_BTS = 5.0

V_total = 5186.99

# Googled
C_SA = 28.4
C_PA = C_SA * 7
C_SV = 124
C_PV = C_SV * 7

# From table 4
# Atrium
E_min_a = 1.2
E_max_a = 12
t_onset_a = 0.85
m_1a = 3
tau_1a = 0.11
m_2a = 27
tau_2a = 0.18

# Ventricle
E_min_v = 1.2
E_max_v = 120
t_onset_v = 0.0
m_1v = 3
tau_1v = 0.27
m_2v = 27
tau_2v = 0.45

# x_0 = [p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SA, Q_SV, Q_PA, Q_PV, P_SA, P_SV, P_PA, P_PV]
# Really only and p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SV, Q_PV, and P_SA are need so the others can be set to zero. 
params = dict(
        dt=dt,
        HR=HR,
        V_a0=V_a0, V_v0=V_v0,
        E_min_a=E_min_a, E_max_a=E_max_a, t_onset_a=t_onset_a, m_1a=m_1a, tau_1a=tau_1a, m_2a=m_2a, tau_2a=tau_2a,
        E_min_v=E_min_v, E_max_v=E_max_v, t_onset_v=t_onset_v, m_1v=m_1v, tau_1v=tau_1v, m_2v=m_2v, tau_2v=tau_2v,
        K_a=K_a, K_v=K_v,
        gamma_int=gamma_int, gamma_ext=gamma_ext,
        L_int=L_int, L_ext=L_ext, B_int=B_int, B_ext=B_ext, R_int=R_int, R_ext=R_ext,
        R_s=R_s, R_p=R_p, R_BTS=R_BTS,
        C_SA=C_SA, C_PA=C_PA, C_SV=C_SV, C_PV=C_PV,
        V_total=V_total,
    )

x0 = generate_x0_fixed_point_ra_rv(**params)



time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
                           E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)
# Out:
# /Users/kathrynhu/Documents/norwood/src/fixed_point_init.py:21: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-gamma * delta_p))
# /Users/kathrynhu/Documents/norwood/src/fixed_point_init.py:170: RuntimeWarning: overflow encountered in scalar multiply
#   [-E_a - (K_a * x[0] * x[4] / dt)],
# /Users/kathrynhu/Documents/norwood/src/fixed_point_init.py:171: RuntimeWarning: overflow encountered in scalar multiply
#   [-E_v - (K_v * x[1] * x[5] / dt)],
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[5], line 66
#      50 # x_0 = [p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SA, Q_SV, Q_PA, Q_PV, P_SA, P_SV, P_PA, P_PV]
#      51 # Really only and p_a, p_v, Q_int, Q_ext, V_a, V_v, Q_SV, Q_PV, and P_SA are need so the others can be set to zero.
#      52 params = dict(
#      53         dt=dt,
#      54         HR=HR,
#    (...)
#      63         V_total=V_total,
#      64     )
# ---> 66 x0 = generate_x0_fixed_point_ra_rv(**params)
#      70 time_dependent_norwood(t0, tf, dt, x0, V_a0, V_v0, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, HR,
#      71                            E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v)
#
# File ~/Documents/norwood/src/fixed_point_init.py:187, in generate_x0_fixed_point_ra_rv(dt, HR, t0, V_a0, V_v0, E_min_a, E_max_a, t_onset_a, m_1a, tau_1a, m_2a, tau_2a, E_min_v, E_max_v, t_onset_v, m_1v, tau_1v, m_2v, tau_2v, K_a, K_v, gamma_int, gamma_ext, L_int, L_ext, B_int, B_ext, R_int, R_ext, R_s, R_p, R_BTS, C_SA, C_PA, C_SV, C_PV, V_total, max_iter, tol, relaxation)
#     169 b = np.array([
#     170     [-E_a - (K_a * x[0] * x[4] / dt)],
#     171     [-E_v - (K_v * x[1] * x[5] / dt)],
#    (...)
#     183     [V_total],
#     184 ], dtype=float)
#     186 # Solve; relax; check convergence
# --> 187 x_sol = np.linalg.solve(A, b).reshape(-1)
#     188 x_new = (1.0 - relaxation) * x + relaxation * x_sol
#     190 if np.linalg.norm(x_new - x, ord=np.inf) < tol:
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:409, in solve(a, b)
#     407 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     408 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 409 r = gufunc(a, b, signature=signature, extobj=extobj)
#     411 return wrap(r.astype(result_t, copy=False))
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
